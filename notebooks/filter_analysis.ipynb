# %% [markdown]
# # Filter Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_cam1 = pd.read_csv('../data/unnested_data/data1.csv')
df_cam2 = pd.read_csv('../data/unnested_data/data2.csv')
df_cam3 = pd.read_csv('../data/unnested_data/data3.csv')
df_cam4 = pd.read_csv('../data/unnested_data/data4.csv')
df_cam5 = pd.read_csv('../data/unnested_data/data5.csv')
df_cam6 = pd.read_csv('../data/unnested_data/data6.csv')
df_cam7 = pd.read_csv('../data/unnested_data/data7.csv')
df_cam8 = pd.read_csv('../data/unnested_data/data8.csv')
df_cam9 = pd.read_csv('../data/unnested_data/data9.csv')
df_cam10 = pd.read_csv('../data/unnested_data/data10.csv')
df_cam11 = pd.read_csv('../data/unnested_data/data11.csv')
df_cam13 = pd.read_csv('../data/unnested_data/data13.csv')
df_cam14 = pd.read_csv('../data/unnested_data/data14.csv')

df_res1 = pd.read_csv('../data/plank_results1-7.csv')
df_res2 = pd.read_csv('../data/plank_results8-11.csv')
df_res3 = pd.read_csv('../data/plank_results13-14.csv')

# %%
df_full = pd.concat([df_cam1, df_cam2, df_cam3, df_cam4, df_cam5, df_cam6, df_cam7, df_cam8, df_cam9, df_cam10, df_cam11, df_cam13, df_cam14])
df_plank = pd.concat([df_res1, df_res2, df_res3])

df_plank.drop_duplicates(inplace=True)
df_plank.shape
# Out:
# (754543, 3)

# %%
X = df_plank.value_counts('plank')

sns.barplot(x=X.index, y=X.values)
X
# Out:
# plank
# 1.0    705633
# 0.0     48910
# dtype: int64
